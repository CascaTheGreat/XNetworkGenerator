# %%
import re
import time
from playwright.async_api import async_playwright
from bs4 import BeautifulSoup
import json

# %%
async def main():
    async with async_playwright() as p:
        browser = await p.chromium.connect_over_cdp("http://localhost:9222")
        default_context = browser.contexts[0]
        page = default_context.pages[0]
        await page.goto("https://truthsocial.com/search")
        time.sleep(3.2)  # Wait for the page to load completely
        await page.locator("button:text('Topics')").click()
        time.sleep(0.7)  # Wait for the topics to load

        #scroll down the page 35 px to load more topics
        #Truth uses agressive culling to only load a few topics at a time, this forces it to load more
        await page.evaluate("window.scrollBy(0, 90);")

        #find the div with id search-results
        search_results = page.locator("div#search-results")

        with open("truthsocial.html", "w") as f:
            f.write(await search_results.inner_html())

        await browser.close()

await main()

# %%
with open("truthsocial.html", "r") as f_html:
    soup = BeautifulSoup(f_html, "html.parser")

topic_links = soup.find_all("a")
for link in topic_links:
    print(link['href'].replace('/tags/', '', 1))

num_posts = soup.find_all("span")
numbers = []
for post in num_posts:
    if post.text.isnumeric() or re.match(r'^\d+(\.\d+)?[KkMm]$', post.text):
        numbers.append(post.text)
        print(post.text)

lines = soup.find_all("svg")
for line in lines:
    print(line)

outputJson = {"trends": []}
for i in range(len(topic_links)):
    topic = topic_links[i]['href'].replace('/tags/', '', 1)
    posts = numbers[i] if i < len(numbers) else "0"
    svg = str(lines[i]) if i < len(lines) else ""
    if svg.startswith("<svg "):
        svg = svg.replace("<svg preserveaspectratio=\"none\"", "<svg xmlns=\"http://www.w3.org/2000/svg\" ", 1)
        svg = svg.replace("\n", " ")
        #remove uneeded spaces
        svg = re.sub(r'\s+', ' ', svg).strip()
    outputJson["trends"].append({"topic": topic, "posts": posts, "svg": svg})

with open("truth.json", "w") as f_json:
    json.dump(outputJson, f_json, indent=4)
# Out:
# Iran
# Trump
# Israel
# MAGA
# NoWarWithIran
# IsraelIranWar
# America
# IStandWithPresidentTrump
# Truth
# winning
# WWG1WGA
# kristinoem
# RescueAndRestore
# AmericaFirst
# 4.63k
# 8.01k
# 4.37k
# 16.6k
# 363
# 317
# 1.3k
# 259
# 10.1k
# 298
# 2.86k
# 81
# 14
# 5.43k
# <svg preserveaspectratio="none" viewbox="0 0 40 28">
# <g>
# <path d="M2 26 C 3.5 26 6.5 13.904509283819628 8 13.904509283819628 C 9.5 13.904509283819628 12.5 12.312997347480106 14 12.312997347480106 C 15.5 12.312997347480106 18.5 19.69761273209549 20 19.69761273209549 C 21.5 19.69761273209549 24.5 18.870026525198938 26 18.870026525198938 C 27.5 18.870026525198938 30.5 9.066312997347481 32 9.066312997347481 C 33.5 9.066312997347481 36.5 2 38 2 L38 26 2 26 2 26" style="
#                   stroke: none;
#                   stroke-width: 0;
#                   fill-opacity: 0.1;
#                   fill: none;
#                 "></path>
# <path d="M2 26 C 3.5 26 6.5 13.904509283819628 8 13.904509283819628 C 9.5 13.904509283819628 12.5 12.312997347480106 14 12.312997347480106 C 15.5 12.312997347480106 18.5 19.69761273209549 20 19.69761273209549 C 21.5 19.69761273209549 24.5 18.870026525198938 26 18.870026525198938 C 27.5 18.870026525198938 30.5 9.066312997347481 32 9.066312997347481 C 33.5 9.066312997347481 36.5 2 38 2" style="
#                   stroke: rgb(129, 140, 248);
#                   stroke-width: 1;
#                   stroke-linejoin: round;
#                   stroke-linecap: round;
#                   fill: none;
#                 "></path>
# </g>
# </svg>
# <svg preserveaspectratio="none" viewbox="0 0 40 28">
# <g>
# <path d="M2
style="
#                   stroke: none;
#                   stroke-width: 0;
#                   fill-opacity: 0.1;
#                   fill: none;
#                 "></path>
# <path d="M2 3.5 C 3.5 3.5 6.5 3.5 8 3.5 C 9.5 3.5 12.5 18.5 14 18.5 C 15.5 18.5 18.5 17 20 17 C 21.5 17 24.5 26 26 26 C 27.5 26 30.5 23 32 23 C 33.5 23 36.5 2 38 2" style="
#                   stroke: rgb(129, 140, 248);
#                   stroke-width: 1;
#                   stroke-linejoin: round;
#                   stroke-linecap: round;
#                   fill: none;
#                 "></path>
# </g>
# </svg>
# <svg preserveaspectratio="none" viewbox="0 0 40 28">
# <g>
# <path d="M2 4.4 C 3.5 4.4 6.5 4.4 8 4.4 C 9.5 4.4 12.5 14 14 14 C 15.5 14 18.5 6.8 20 6.8 C 21.5 6.8 24.5 26 26 26 C 27.5 26 30.5 16.4 32 16.4 C 33.5 16.4 36.5 2 38 2 L38 26 2 26 2 4.4" style="
#                   stroke: none;
#                   stroke-width: 0;
#                   fill-opacity: 0.1;
#                   fill: none;
#                 "></path>
# <path d="M2 4.4 C 3.5 4.4 6.5 4.4 8 4.4 C 9.5 4.4 12.5 14 14 14 C 15.5 14 18.5 6.8 20 6.8 C 21.5 6.8 24.5 26 26 26 C 27.5 26 30.5 16.4 32 16.4 C 33.5 16.4 36.5 2 38 2" style="
#                   stroke: rgb(129, 140, 248);
#                   stroke-width: 1;
#                   stroke-linejoin: round;
#                   stroke-linecap: round;
#                   fill: none;
#                 "></path>
# </g>
# </svg>
# <svg preserveaspectratio="none" viewbox="0 0 40 28">
# <g>
# <path d="M2 24.285714285714285 C 3.5 24.285714285714285 6.5 2 8 2 C 9.5 2 12.5 14.857142857142856 14 14.857142857142856 C 15.5 14.857142857142856 18.5 24.285714285714285 20 24.285714285714285 C 21.5 24.285714285714285 24.5 22.57142857142857 26 22.57142857142857 C 27.5 22.57142857142857 30.5 26 32 26 C 33.5 26 36.5 12.285714285714285 38 12.285714285714285 L38 26 2 26 2 24.285714285714285" style="
#                   stroke: none;
#                   stroke-width: 0;
#                   fill-opacity: 0.1;
#                   fill: none;
#                 "></path>
# <path d="M2 24.285714285714285 C 3.5 24.285714285714285 6.5 2 8 2 C 9.5 2 12.5 14.857142857142856 14 14.857142857142856 C 15.5 14.857142857142856 18.5 24.285714285714285 20 24.285714285714285 C 21.5 24.285714285714285 24.5 22.57142857142857 26 22.57142857142857 C 27.5 22.57142857142857 30.5 26 32 26 C 33.5 26 36.5 12.285714285714285 38 12.285714285714285" style="
#                   stroke: rgb(129, 140, 248);
#                   stroke-width: 1;
#                   stroke-linejoin: round;
#                   stroke-linecap: round;
#                   fill: none;
#                 "></path>
# </g>
# </svg>
# <svg preserveaspectratio="none" viewbox="0 0 40 28">
# <g>
# <path d="M2 26 C 3.5 26 6.5 26 8 26 C 9.5 26 12.5 26 14 26 C 15.5 26 18.5 26 20 26 C 21.5 26 24.5 26 26 26 C 27.5 26 30.5 26 32 26 C 33.5 26 36.5 2 38 2 L38 26 2 26 2 26" style="
#                   stroke: none;
#                   stroke-width: 0;
#                   fill-opacity: 0.1;
#                   fill: none;
#                 "></path>
# <path d="M2 26 C 3.5 26 6.5 26 8 26 C 9.5 26 12.5 26 14 26 C 15.5 26 18.5 26 20 26 C 21.5 26 24.5 26 26 26 C 27.5 26 30.5 26 32 26 C 33.5 26 36.5 2 38 2" style="
#                   stroke: rgb(129, 140, 248);
#                   stroke-width: 1;
#                   stroke-linejoin: round;
#                   stroke-linecap: round;
#                   fill: none;
#                 "></path>
# </g>
# </svg>
# <svg preserveaspectratio="none" viewbox="0 0 40 28">
# <g>
# <path d="M2 26 C 3.5 26 6.5 22.7 8 22.7 C 9.5 22.7 12.5 12.5 14 12.5 C 15.5 12.5 18.5 20.3 20 20.3 C 21.5 20.3 24.5 25.4 26 25.4 C 27.5 25.4 30.5 2 32 2 C 33.5 2 36.5 3.2 38 3.2 L38 26 2 26 2 26" style="
#                   stroke: none;
#                   stroke-width: 0;
#                   fill-opacity: 0.1;
#                   fill: none;
#                 "></path>
# <path d="M2 26 C 3.5 26 6.5 22.7 8 22.7 C 9.5 22.7 12.5 12.5 14 12.5 C 15.5 12.5 18.5 20.3 20 20.3 C 21.5 20.3 24.5 25.4 26 25.4 C 27.5 25.4 30.5 2 32 2 C 33.5 2 36.5 3.2 38 3.2" style="
#                   stroke: rgb(129, 140, 248);
#                   stroke-width: 1;
#                   stroke-linejoin: round;
#                   stroke-linecap: round;
#                   fill: none;
#                 "></path>
# </g>
# </svg>
